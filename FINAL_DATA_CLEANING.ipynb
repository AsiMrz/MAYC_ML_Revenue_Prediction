# %% [markdown]
# # Google Analytics user_prediction challenge

# %% [markdown]
# ## Cleaning Data

# %%
# download the libraries
import pandas as pd
from pandas import Series,DataFrame
import warnings
from copy import deepcopy
import os
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import random
# %matplotlib inline

# %%
# load both of the datasets
traindata = pd.read_pickle('train_flat_no_hits.pkl')
testdata = pd.read_pickle('test_flat_no_hits.pkl')

# %%
# add a marker so that you know which dataset is which
traindata['dataset'] = 'train'
testdata['dataset'] = 'test'

# %%
# See train columns
traindata.columns
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'socialEngagementType',
#        'visitId', 'visitNumber', 'visitStartTime', 'device.browser',
#        'device.browserVersion', 'device.browserSize', 'device.operatingSystem',
#        'device.operatingSystemVersion', 'device.isMobile',
#        'device.mobileDeviceBranding', 'device.mobileDeviceModel',
#        'device.mobileInputSelector', 'device.mobileDeviceInfo',
#        'device.mobileDeviceMarketingName', 'device.flashVersion',
#        'device.language', 'device.screenColors', 'device.screenResolution',
#        'device.deviceCategory', 'geoNetwork.continent',
#        'geoNetwork.subContinent', 'geoNetwork.country', 'geoNetwork.region',
#        'geoNetwork.metro', 'geoNetwork.city', 'geoNetwork.cityId',
#        'geoNetwork.networkDomain', 'geoNetwork.latitude',
#        'geoNetwork.longitude', 'geoNetwork.networkLocation', 'totals.visits',
#        'totals.hits', 'totals.pageviews', 'totals.bounces', 'totals.newVisits',
#        'totals.sessionQualityDim', 'totals.timeOnSite', 'totals.transactions',
#        'totals.transactionRevenue', 'totals.totalTransactionRevenue',
#        'trafficSource.campaign', 'trafficSource.source',
#        'trafficSource.medium', 'trafficSource.keyword',
#        'trafficSource.adwordsClickInfo.criteriaParameters',
#        'trafficSource.referralPath', 'trafficSource.isTrueDirect',
#        'trafficSource.adContent', 'trafficSource.adwordsClickInfo.page',
#        'trafficSource.adwordsClickInfo.slot',
#        'trafficSource.adwordsClickInfo.gclId',
#        'trafficSource.adwordsClickInfo.adNetworkType',
#        'trafficSource.adwordsClickInfo.isVideoAd',
#        'trafficSource.campaignCode', 'customDimension.index',
#        'customDimension.value', 'dataset'],
#       dtype='object')

# %%
# See test columns
testdata.columns
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'socialEngagementType',
#        'visitId', 'visitNumber', 'visitStartTime', 'device.browser',
#        'device.browserVersion', 'device.browserSize', 'device.operatingSystem',
#        'device.operatingSystemVersion', 'device.isMobile',
#        'device.mobileDeviceBranding', 'device.mobileDeviceModel',
#        'device.mobileInputSelector', 'device.mobileDeviceInfo',
#        'device.mobileDeviceMarketingName', 'device.flashVersion',
#        'device.language', 'device.screenColors', 'device.screenResolution',
#        'device.deviceCategory', 'geoNetwork.continent',
#        'geoNetwork.subContinent', 'geoNetwork.country', 'geoNetwork.region',
#        'geoNetwork.metro', 'geoNetwork.city', 'geoNetwork.cityId',
#        'geoNetwork.networkDomain', 'geoNetwork.latitude',
#        'geoNetwork.longitude', 'geoNetwork.networkLocation', 'totals.visits',
#        'totals.hits', 'totals.pageviews', 'totals.timeOnSite',
#        'totals.sessionQualityDim', 'totals.newVisits', 'totals.transactions',
#        'totals.transactionRevenue', 'totals.totalTransactionRevenue',
#        'totals.bounces', 'trafficSource.referralPath',
#        'trafficSource.campaign', 'trafficSource.source',
#        'trafficSource.medium', 'trafficSource.keyword',
#        'trafficSource.adContent', 'trafficSource.isTrueDirect',
#        'trafficSource.adwordsClickInfo.criteriaParameters',
#        'trafficSource.adwordsClickInfo.page',
#        'trafficSource.adwordsClickInfo.slot',
#        'trafficSource.adwordsClickInfo.gclId',
#        'trafficSource.adwordsClickInfo.adNetworkType',
#        'trafficSource.adwordsClickInfo.isVideoAd', 'customDimension.index',
#        'customDimension.value', 'dataset'],
#       dtype='object')

# %%
# make sure the columns are in the same order in both train and test.
# the deepcopy is just to have a copy of the original even after joining them
col_order = list(set(traindata.columns.tolist() + testdata.columns.tolist()))
traindata = deepcopy(traindata[col_order])
testdata = deepcopy(testdata[col_order])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-372976850aa0> in <module>
#       3 col_order = list(set(traindata.columns.tolist() + testdata.columns.tolist()))
#       4 traindata = deepcopy(traindata[col_order])
# ----> 5 testdata = deepcopy(testdata[col_order])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1643             if not (self.name == "loc" and not raise_missing):
#    1644                 not_found = list(set(key) - set(ax))
# -> 1645                 raise KeyError(f"{not_found} not in index")
#    1646
#    1647             # we skip the warning on Categorical/Interval
#
# KeyError: "['trafficSource.campaignCode'] not in index"

# %%
#the test doesnt have trafficSource.campaignCode column, so i droped it from the train set
traindata.drop('trafficSource.campaignCode',axis=1,inplace= True)

# %%
#Repeat 
col_order = list(set(traindata.columns.tolist() + testdata.columns.tolist()))
traindata = deepcopy(traindata[col_order])
testdata = deepcopy(testdata[col_order])

# %%
#Merge both data set
all_data = traindata[col_order].append(testdata)

# %%
# view the Merged dataset
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2109926 entries, 0 to 401588
# Data columns (total 60 columns):
#  #   Column                                             Dtype
# ---  ------                                             -----
#  0   device.operatingSystem                             object
#  1   date                                               int64
#  2   device.mobileDeviceModel                           object
#  3   device.mobileDeviceMarketingName                   object
#  4   totals.hits                                        object
#  5   totals.visits                                      object
#  6   device.screenResolution                            object
#  7   geoNetwork.longitude                               object
#  8   geoNetwork.region                                  object
#  9   trafficSource.keyword                              object
#  10  socialEngagementType                               object
#  11  totals.pageviews                                   object
#  12  totals.totalTransactionRevenue                     object
#  13  trafficSource.campaign                             object
#  14  geoNetwork.latitude                                object
#  15  trafficSource.isTrueDirect                         object
#  16  trafficSource.adwordsClickInfo.isVideoAd           object
#  17  channelGrouping                                    object
#  18  device.screenColors                                object
#  19  visitStartTime                                     int64
#  20  geoNetwork.country                                 object
#  21  trafficSource.adwordsClickInfo.slot                object
#  22  geoNetwork.city                                    object
#  23  totals.bounces                                     object
#  24  device.operatingSystemVersion                      object
#  25  totals.sessionQualityDim                           object
#  26  device.mobileDeviceBranding                        object
#  27  device.mobileDeviceInfo                            object
#  28  device.language                                    object
#  29  trafficSource.adwordsClickInfo.gclId               object
#  30  trafficSource.source                               object
#  31  device.browserVersion                              object
#  32  visitId                                            int64
#  33  totals.transactions                                object
#  34  device.browserSize                                 object
#  35  dataset                                            object
#  36  trafficSource.adContent                            object
#  37  visitNumber                                        int64
#  38  geoNetwork.networkDomain                           object
#  39  totals.transactionRevenue                          object
#  40  trafficSource.referralPath                         object
#  41  device.mobileInputSelector                         object
#  42  geoNetwork.continent                               object
#  43  totals.timeOnSite                                  object
#  44  geoNetwork.subContinent                            object
#  45  totals.newVisits                                   object
#  46  geoNetwork.networkLocation                         object
#  47  fullVisitorId                                      object
#  48  device.browser                                     object
#  49  geoNetwork.cityId                                  object
#  50  customDimension.value                              object
#  51  device.deviceCategory                              object
#  52  device.flashVersion                                object
#  53  trafficSource.medium                               object
#  54  trafficSource.adwordsClickInfo.adNetworkType       object
#  55  device.isMobile                                    bool
#  56  trafficSource.adwordsClickInfo.criteriaParameters  object
#  57  customDimension.index                              object
#  58  trafficSource.adwordsClickInfo.page                object
#  59  geoNetwork.metro                                   object
# dtypes: bool(1), int64(4), object(55)
# memory usage: 967.9+ MB

# %%
#define a function to look for missing data
def values_missing(check):
    total = check.isnull().sum().sort_values(ascending = False) # getting the sum of null values and ordering
    percent = (check.isnull().sum() / check.isnull().count() * 100 ).sort_values(ascending = False) #getting the percent and order of null
    df_train = pd.concat([total, percent], axis=1, keys=['Total', 'Percent']) # Concatenating the total and percent
    print("Total and percent of missing values: ")
    print (df_train[~(df_train['Total'] == 0)]) # Returning values of nulls different of 0
    
    return

# %%
#define a function to investigate the columns  

def see_data(data, data_type=object, limit=5): #seting the function with data,show 5 uniques if available 
    n = data.select_dtypes(include=data_type) #selecting the desired data type
    for column in n.columns: #initializing the loop
        print("_________________________________________________________")
        print("Column Name ", column, ': \n', "Uniques: ", data[column].unique()[:limit], "\n",
              " | >>>> Total nulls: ", (round(data[column].isnull().sum() / len(data[column]) * 100,1)),
              " | >>>> Total unique values: ", all_data.nunique()[column]) #print the data and % of nulls)
        print("_________________________________________________________")

# %%
#Check missing values
values_missing(all_data)
# Out:
# Total and percent of missing values:
#                                                 Total    Percent
# totals.transactionRevenue                     2086818  98.904796
# totals.totalTransactionRevenue                2086818  98.904796
# totals.transactions                           2085062  98.821570
# trafficSource.adwordsClickInfo.slot           2024047  95.929762
# trafficSource.adwordsClickInfo.page           2024047  95.929762
# trafficSource.adwordsClickInfo.adNetworkType  2024047  95.929762
# trafficSource.adwordsClickInfo.isVideoAd      2024047  95.929762
# trafficSource.adwordsClickInfo.gclId          2023891  95.922369
# trafficSource.adContent                       1643600  77.898467
# trafficSource.isTrueDirect                    1426999  67.632656
# trafficSource.referralPath                    1142073  54.128581
# trafficSource.keyword                         1093006  51.803049
# totals.timeOnSite                             1057980  50.142991
# totals.bounces                                1055670  50.033508
# totals.sessionQualityDim                       835274  39.587834
# totals.newVisits                               516431  24.476261
# customDimension.index                          393816  18.664920
# customDimension.value                          393816  18.664920
# totals.pageviews                                  340   0.016114

# %%
see_data(all_data)
# Out:
# _________________________________________________________
# Column Name  device.operatingSystem :
#  Uniques:  ['Windows' 'Chrome OS' 'Android' 'Macintosh' 'iOS']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  26
# _________________________________________________________
# _________________________________________________________
# Column Name  device.mobileDeviceModel :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  device.mobileDeviceMarketingName :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  totals.hits :
#  Uniques:  ['1' '2' '3' '4' '5']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  308
# _________________________________________________________
# _________________________________________________________
# Column Name  totals.visits :
#  Uniques:  ['1']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  device.screenResolution :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  geoNetwork.longitude :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  geoNetwork.region :
#  Uniques:  ['not available in demo dataset' 'California' 'England' 'Mexico City'
#  'Nevada']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  518
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.keyword :
#  Uniques:  ['water bottle' nan '(not provided)' '(Remarketing/Content targeting)'
#  '6qEhsCssdK0z36ri']
#   | >>>> Total nulls:  51.8  | >>>> Total unique values:  4996
# _________________________________________________________
# _________________________________________________________
# Column Name  socialEngagementType :
#  Uniques:  ['Not Socially Engaged']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  totals.pageviews :
#  Uniques:  ['1' '2' '3' '4' '5']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  241
# _________________________________________________________
# _________________________________________________________
# Column Name  totals.totalTransactionRevenue :
#  Uniques:  [nan '17190000' '13000000' '65300000' '25230000']
#   | >>>> Total nulls:  98.9  | >>>> Total unique values:  9728
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.campaign :
#  Uniques:  ['(not set)' '"google + redesign/Accessories March 17" All Users'
#  'AW - Dynamic Search Ads Whole Site'
#  '1000557 | GA | US | en | Hybrid | GDN Text+Banner | AS'
#  'Data Share Promo']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  42
# _________________________________________________________
# _________________________________________________________
# Column Name  geoNetwork.latitude :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.isTrueDirect :
#  Uniques:  [nan True]
#   | >>>> Total nulls:  67.6  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.adwordsClickInfo.isVideoAd :
#  Uniques:  [nan False]
#   | >>>> Total nulls:  95.9  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  channelGrouping :
#  Uniques:  ['Organic Search' 'Referral' 'Direct' 'Paid Search' 'Display']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  8
# _________________________________________________________
# _________________________________________________________
# Column Name  device.screenColors :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  geoNetwork.country :
#  Uniques:  ['Germany' 'United States' 'Turkey' 'Mexico' 'United Kingdom']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  229
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.adwordsClickInfo.slot :
#  Uniques:  [nan 'Top' 'RHS' 'Google Display Network' 'Google search: Top']
#   | >>>> Total nulls:  95.9  | >>>> Total unique values:  5
# _________________________________________________________
# _________________________________________________________
# Column Name  geoNetwork.city :
#  Uniques:  ['not available in demo dataset' 'Cupertino' 'San Francisco' 'London'
#  'Mexico City']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1097
# _________________________________________________________
# _________________________________________________________
# Column Name  totals.bounces :
#  Uniques:  ['1' nan]
#   | >>>> Total nulls:  50.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  device.operatingSystemVersion :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  totals.sessionQualityDim :
#  Uniques:  ['1' '2' '3' '4' '6']
#   | >>>> Total nulls:  39.6  | >>>> Total unique values:  100
# _________________________________________________________
# _________________________________________________________
# Column Name  device.mobileDeviceBranding :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  device.mobileDeviceInfo :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  device.language :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.adwordsClickInfo.gclId :
#  Uniques:  [nan
#  'Cj0KCQjwsZHPBRClARIsAC-VMPBHdNF2oMOgh6Xp6YhjXWSk11sDu3eCo4De_u6l4xafqgrPVPSGYdkaArkiEALw_wcB'
#  'CODVoMjJ9tYCFUIvgQod_dsKEA'
#  'Cj0KCQjwsZHPBRClARIsAC-VMPA4CVJtDhu1lYkB0AR1hje1goUMHQZNJMrsSWD57pLnv1KE_L7pCEcaAunKEALw_wcB'
#  'Cj0KCQjwsZHPBRClARIsAC-VMPDlLD6kS4tmqFGZjMUqyerwe0WDaULaAKNkj-gwuvPnLSPRyf9TN7IaArICEALw_wcB']
#   | >>>> Total nulls:  95.9  | >>>> Total unique values:  67994
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.source :
#  Uniques:  ['google' 'sites.google.com' '(direct)' 'analytics.google.com'
#  'blog.golang.org']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  391
# _________________________________________________________
# _________________________________________________________
# Column Name  device.browserVersion :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  totals.transactions :
#  Uniques:  [nan '1' '2' '3' '4']
#   | >>>> Total nulls:  98.8  | >>>> Total unique values:  14
# _________________________________________________________
# _________________________________________________________
# Column Name  device.browserSize :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  dataset :
#  Uniques:  ['train' 'test']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  2
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.adContent :
#  Uniques:  [nan 'Placement Accessories 300 x 250' 'Google Merchandise Store'
#  'Bags 300x250' 'Display Ad created 3/11/14']
#   | >>>> Total nulls:  77.9  | >>>> Total unique values:  100
# _________________________________________________________
# _________________________________________________________
# Column Name  geoNetwork.networkDomain :
#  Uniques:  ['(not set)' 'windjammercable.net' 'unknown.unknown'
#  'prod-infinitum.com.mx' 'fullrate.ninja']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  48405
# _________________________________________________________
# _________________________________________________________
# Column Name  totals.transactionRevenue :
#  Uniques:  [nan '15190000' '8000000' '57300000' '18230000']
#   | >>>> Total nulls:  98.9  | >>>> Total unique values:  8219
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.referralPath :
#  Uniques:  [nan '/a/google.com/transportation/mtv-services/bikes/bike2workmay2016'
#  '/offer/2145' '/a/google.com/nest-vision/dropcam-field-tester-program'
#  '/analytics/web/']
#   | >>>> Total nulls:  54.1  | >>>> Total unique values:  3757
# _________________________________________________________
# _________________________________________________________
# Column Name  device.mobileInputSelector :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  geoNetwork.continent :
#  Uniques:  ['Europe' 'Americas' 'Asia' 'Oceania' '(not set)']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  6
# _________________________________________________________
# _________________________________________________________
# Column Name  totals.timeOnSite :
#  Uniques:  [nan '28' '38' '1' '52']
#   | >>>> Total nulls:  50.1  | >>>> Total unique values:  5002
# _________________________________________________________
# _________________________________________________________
# Column Name  geoNetwork.subContinent :
#  Uniques:  ['Western Europe' 'Northern America' 'Western Asia' 'Central America'
#  'Northern Europe']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  23
# _________________________________________________________
# _________________________________________________________
# Column Name  totals.newVisits :
#  Uniques:  ['1' nan]
#   | >>>> Total nulls:  24.5  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  geoNetwork.networkLocation :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  fullVisitorId :
#  Uniques:  ['3162355547410993243' '8934116514970143966' '7992466427990357681'
#  '9075655783635761930' '6960673291025684308']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1617501
# _________________________________________________________
# _________________________________________________________
# Column Name  device.browser :
#  Uniques:  ['Firefox' 'Chrome' 'Safari' 'UC Browser' 'Internet Explorer']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  161
# _________________________________________________________
# _________________________________________________________
# Column Name  geoNetwork.cityId :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  customDimension.value :
#  Uniques:  ['EMEA' 'North America' 'Central America' nan 'APAC']
#   | >>>> Total nulls:  18.7  | >>>> Total unique values:  5
# _________________________________________________________
# _________________________________________________________
# Column Name  device.deviceCategory :
#  Uniques:  ['desktop' 'mobile' 'tablet']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  3
# _________________________________________________________
# _________________________________________________________
# Column Name  device.flashVersion :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.medium :
#  Uniques:  ['organic' 'referral' '(none)' 'cpc' 'affiliate']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  7
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.adwordsClickInfo.adNetworkType :
#  Uniques:  [nan 'Google Search' 'Content' 'Search partners']
#   | >>>> Total nulls:  95.9  | >>>> Total unique values:  3
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.adwordsClickInfo.criteriaParameters :
#  Uniques:  ['not available in demo dataset']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  customDimension.index :
#  Uniques:  ['4' nan]
#   | >>>> Total nulls:  18.7  | >>>> Total unique values:  1
# _________________________________________________________
# _________________________________________________________
# Column Name  trafficSource.adwordsClickInfo.page :
#  Uniques:  [nan '1' '3' '2' '5']
#   | >>>> Total nulls:  95.9  | >>>> Total unique values:  11
# _________________________________________________________
# _________________________________________________________
# Column Name  geoNetwork.metro :
#  Uniques:  ['not available in demo dataset' 'San Francisco-Oakland-San Jose CA'
#  'London' '(not set)' 'JP_KANTO']
#   | >>>> Total nulls:  0.0  | >>>> Total unique values:  130
# _________________________________________________________

# %%
# decision  process to drop some coluns with unique values(mostly 'not in the demoset') while some will left.

# %%
drop_col_list = ['socialEngagementType', 'device.browserVersion', 'device.browserSize', 'device.operatingSystemVersion',
                 'device.mobileDeviceBranding', 'device.mobileDeviceModel', 'device.mobileInputSelector', 
                 'device.mobileDeviceInfo', 'device.mobileDeviceMarketingName', 'device.flashVersion', 'device.language', 
                 'device.screenColors', 'device.screenResolution', 'geoNetwork.cityId', 'geoNetwork.latitude', 
                 'geoNetwork.longitude', 'geoNetwork.networkLocation', 'trafficSource.campaign', 'trafficSource.referralPath', 
                 'trafficSource.adwordsClickInfo.slot', 
                 'trafficSource.adwordsClickInfo.criteriaParameters', 'trafficSource.adContent', 'trafficSource.adwordsClickInfo.gclId', 
                 'customDimension.index']

# %%
all_data.drop(drop_col_list, axis=1, inplace=True)  #to drop them

# %%
# filling relevant columns

# %%
all_data['totals.pageviews'].fillna(0, inplace=True) #filling NA's with 1(since least for a visit to the site means 1 page seen)
all_data['totals.newVisits'].fillna(0, inplace=True) #filling NA's with 0(0 is suitable for Nan here)
all_data['totals.bounces'].fillna(0, inplace=True)   #filling NA's with 0(0 is suitable for Nan here)
all_data["totals.transactionRevenue"] = all_data["totals.transactionRevenue"].fillna(0.0).astype(float) #filling NA with zero
all_data["totals.totalTransactionRevenue"] = all_data["totals.totalTransactionRevenue"].fillna(0.0).astype(float) #filling NA with zero
all_data["totals.transactionRevenue"] = all_data["totals.transactionRevenue"].fillna(0.0).astype(float) #filling NA with zero
all_data["totals.transactions"] = all_data["totals.transactions"].fillna(0).astype(int) #filling NA with zero
all_data['trafficSource.isTrueDirect'].fillna(False, inplace=True) # filling boolean with False is its NAn
all_data['trafficSource.adwordsClickInfo.isVideoAd'].fillna(True, inplace=True) # filling boolean is its NAn
all_data['trafficSource.adwordsClickInfo.page'].fillna(0,inplace=True)
all_data['customDimension.value'].fillna('(not set)', inplace=True) # filling NA with '(not set)'
all_data['trafficSource.adwordsClickInfo.adNetworkType'].fillna('(not set)', inplace=True) # filling NA with '(not set)'
all_data['totals.timeOnSite'].fillna(0, inplace=True) #filling NA's with 0(0 is suitable for Nan here)
all_data['totals.sessionQualityDim'].fillna(0, inplace=True) #filling NA's with 0(0 is suitable for Nan here)
#To convert
all_data['totals.pageviews'] = all_data['totals.pageviews'].astype(int) # setting numerical column as integer
all_data['totals.newVisits'] = all_data['totals.newVisits'].astype(int) # setting numerical column as integer
all_data['totals.bounces'] = all_data['totals.bounces'].astype(int)  # setting numerical column as integer
all_data["totals.hits"] = all_data["totals.hits"].astype(float) # setting numerical to float
all_data['totals.sessionQualityDim'] = all_data['totals.sessionQualityDim'].astype(int)
all_data['totals.timeOnSite'] = all_data['totals.timeOnSite'].astype(int)
all_data['date'] = pd.to_datetime(all_data["date"], format="%Y%m%d") #convert to datetime
all_data['geoNetwork.metro'].replace({"not available in demo dataset": "(not set)"}, inplace=True)
all_data['geoNetwork.metro'].replace({"not available in demo dataset": "(not set)"}, inplace=True)

# %%
#view the dataset after dropping and modifying
all_data.head()
# Out:
#   device.operatingSystem       date  totals.hits totals.visits  \
# 0                Windows 2017-10-16          1.0             1
# 1              Chrome OS 2017-10-16          2.0             1
# 2                Android 2017-10-16          2.0             1
# 3                Windows 2017-10-16          2.0             1
# 4                Windows 2017-10-16          2.0             1
#
#                geoNetwork.region trafficSource.keyword  totals.pageviews  \
# 0  not available in demo dataset          water bottle                 1
# 1                     California                   NaN                 2
# 2  not available in demo dataset                   NaN                 2
# 3  not available in demo dataset        (not provided)                 2
# 4  not available in demo dataset        (not provided)                 2
#
#    totals.totalTransactionRevenue  trafficSource.isTrueDirect  \
# 0                             0.0                       False
# 1                             0.0                       False
# 2                             0.0                        True
# 3                             0.0                       False
# 4                             0.0                       False
#
#    trafficSource.adwordsClickInfo.isVideoAd  ... totals.newVisits  \
# 0                                      True  ...                1
# 1                                      True  ...                0
# 2                                      True  ...                1
# 3                                      True  ...                1
# 4                                      True  ...                1
#
#          fullVisitorId device.browser customDimension.value  \
# 0  3162355547410993243        Firefox                  EMEA
# 1  8934116514970143966         Chrome         North America
# 2  7992466427990357681         Chrome         North America
# 3  9075655783635761930         Chrome                  EMEA
# 4  6960673291025684308         Chrome       Central America
#
#    device.deviceCategory  trafficSource.medium  \
# 0                desktop               organic
# 1                desktop              referral
# 2                 mobile                (none)
# 3                desktop               organic
# 4                desktop               organic
#
#   trafficSource.adwordsClickInfo.adNetworkType  device.isMobile  \
# 0                                    (not set)            False
# 1                                    (not set)            False
# 2                                    (not set)             True
# 3                                    (not set)            False
# 4                                    (not set)            False
#
#    trafficSource.adwordsClickInfo.page                   geoNetwork.metro
# 0                                    0                          (not set)
# 1                                    0  San Francisco-Oakland-San Jose CA
# 2                                    0                          (not set)
# 3                                    0                          (not set)
# 4                                    0                          (not set)
#
# [5 rows x 36 columns]

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2109926 entries, 0 to 401588
# Data columns (total 36 columns):
#  #   Column                                        Dtype
# ---  ------                                        -----
#  0   device.operatingSystem                        object
#  1   date                                          datetime64[ns]
#  2   totals.hits                                   float64
#  3   totals.visits                                 object
#  4   geoNetwork.region                             object
#  5   trafficSource.keyword                         object
#  6   totals.pageviews                              int32
#  7   totals.totalTransactionRevenue                float64
#  8   trafficSource.isTrueDirect                    bool
#  9   trafficSource.adwordsClickInfo.isVideoAd      bool
#  10  channelGrouping                               object
#  11  visitStartTime                                int64
#  12  geoNetwork.country                            object
#  13  geoNetwork.city                               object
#  14  totals.bounces                                int32
#  15  totals.sessionQualityDim                      int32
#  16  trafficSource.source                          object
#  17  visitId                                       int64
#  18  totals.transactions                           int32
#  19  dataset                                       object
#  20  visitNumber                                   int64
#  21  geoNetwork.networkDomain                      object
#  22  totals.transactionRevenue                     float64
#  23  geoNetwork.continent                          object
#  24  totals.timeOnSite                             int32
#  25  geoNetwork.subContinent                       object
#  26  totals.newVisits                              int32
#  27  fullVisitorId                                 object
#  28  device.browser                                object
#  29  customDimension.value                         object
#  30  device.deviceCategory                         object
#  31  trafficSource.medium                          object
#  32  trafficSource.adwordsClickInfo.adNetworkType  object
#  33  device.isMobile                               bool
#  34  trafficSource.adwordsClickInfo.page           object
#  35  geoNetwork.metro                              object
# dtypes: bool(3), datetime64[ns](1), float64(3), int32(6), int64(3), object(20)
# memory usage: 585.1+ MB

# %%
#to save as pickle
all_data.to_csv('/Users/chris/Desktop/chris_files.csv/fulldata.csv',index=False)
